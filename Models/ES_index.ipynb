# %%
import ES

dataset = 'ling'
trainingSection = 10

docHeader = dataset
docIndex = dataset + '_' + str(trainingSection)
docType = 'doc'
dataDirPath = ['/Users/SamZhang/Documents/Capstone/dataset/' + dataset + '/train/ham/' + str(trainingSection), 
               '/Users/SamZhang/Documents/Capstone/dataset/' + dataset + '/train/spam/' + str(trainingSection)]

ES.index(docHeader, dataDirPath, docIndex, docType)
# Out:
# {'ling_10': {'mappings': {'doc': {'properties': {'label': {'type': 'text'}, 'content': {'analyzer': 'standard', 'type': 'text'}}}}}}
# ling_train.ham
# CREATING ==> current file Number : ham0 ; 1
# ham
# CREATING ==> current file Number : ham1 ; 2
# ham
# CREATING ==> current file Number : ham2 ; 3
# ham
# CREATING ==> current file Number : ham3 ; 4
# ham
# CREATING ==> current file Number : ham4 ; 5
# ham
# CREATING ==> current file Number : ham5 ; 6
# ham
# CREATING ==> current file Number : ham6 ; 7
# ham
# CREATING ==> current file Number : ham7 ; 8
# ham
# CREATING ==> current file Number : ham8 ; 9
# ham
# CREATING ==> current file Number : ham9 ; 10
# ham
# CREATING ==> current file Number : ham10 ; 11
# ham
# CREATING ==> current file Number : ham11 ; 12
# ham
# CREATING ==> current file Number : ham12 ; 13
# ham
# CREATING ==> current file Number : ham13 ; 14
# ham
# CREATING ==> current file Number : ham14 ; 15
# ham
# CREATING ==> current file Number : ham15 ; 16
# ham
# ...
